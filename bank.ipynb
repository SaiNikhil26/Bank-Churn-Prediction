# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Importing Data**

# %%
data = pd.read_csv("Churn_Modelling.csv")
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %% [markdown]
# # **Data Preprocessing**

# %%
data.shape
# Out:
# (10000, 14)

# %%
data.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.bar(data.columns,data.columns.isna().sum())
plt.xlabel("Columns")
plt.ylabel("Frequency of Null Values")
plt.xticks(rotation=90)
plt.title('Null Value Distribution between columns');

# %% [markdown]
# From the above plot it is clear that there are no Null values in the dataset

# %% [markdown]
# **Dropping unique columns**

# %%
df = data.drop(['RowNumber','CustomerId','Surname'],axis=1)

# %% [markdown]
# **Label Encoding the Categorical Features**

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['Geography'] = encoder.fit_transform(df['Geography'])
df['Gender'] = encoder.fit_transform(df['Gender'])

# %% [markdown]
# # **EDA**

# %%
df.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       0   42       2       0.00              1
# 1          608          2       0   41       1   83807.86              1
# 2          502          0       0   42       8  159660.80              3
# 3          699          0       0   39       1       0.00              2
# 4          850          2       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
plt.figure(figsize=(5,5))
plt.xlabel('Type of Geography')
plt.ylabel('Frequency')
df['Geography'].value_counts().plot(kind='bar',colormap='winter')
countries = ['France', 'Germany', 'Spain']
labels=['France','Germany','Spain']
plt.xticks(range(len(countries)),labels)
plt.title('Plot of People\'s Geographical locations');

# %% [markdown]
# From the above plot it is clear that the dataset contains more people living in France, than both germany and spain. The number of people living in Germany and Spain are almost equal

# %%
plt.figure(figsize=(5,5))
plt.xlabel('Gender')
plt.ylabel('Frequency')
df['Gender'].value_counts().plot(kind='bar',colormap='summer')
plt.xticks(range(0,2),['Male','Female'])
plt.title('Male vs Female');

# %% [markdown]
# From the above Plot, it is clear that Gender is balanced between male and female

# %%
plt.figure(figsize=(5,5))
df['Exited'].value_counts().plot(kind='bar',colormap='autumn')
plt.title('Retain vs Exit')
plt.xlabel('Status of customers')
plt.ylabel('Number of Customer')
plt.xticks(range(0,2),['Retain','Exit']);

# %% [markdown]
# Fom the above plot it is clear that the data is highly imbalanced with the traget variable

# %% [markdown]
# **Correlation Heatmap**

# %%
plt.figure(figsize=(10,10))
plt.title('Correlation HeatMap')
sns.heatmap(df.corr(),annot=True,fmt='.3f',cmap='Blues');

# %% [markdown]
# From the above plot we can infer three things:
# * No. of Products and Balance are highly negatively correlated
# * The exit status of a customer depends on the age and balance significantly
# * Active status of the member is negatively correlated with the exit status of the customer

# %% [markdown]
# # **Balanacing the Data**

# %%
class_count_retain,class_count_exit = df.Exited.value_counts()
class_retain = df[df.Exited == 0]
class_exit = df[df.Exited == 1]
print("Class retain: ",class_retain.shape)
print("Class exit: ",class_exit.shape)
# Out:
# Class retain:  (7963, 11)
# Class exit:  (2037, 11)

# %%
print("Age Statistics of Reatined Customers")
print(class_retain['Age'].describe())
print()
print("Age Statistics of Exited Customer")
print(class_exit['Age'].describe())
# Out:
# Age Statistics of Reatined Customers
# count    7963.000000
# mean       37.408389
# std        10.125363
# min        18.000000
# 25%        31.000000
# 50%        36.000000
# 75%        41.000000
# max        92.000000
# Name: Age, dtype: float64
#
# Age Statistics of Exited Customer
# count    2037.000000
# mean       44.837997
# std         9.761562
# min        18.000000
# 25%        38.000000
# 50%        45.000000
# 75%        51.000000
# max        84.000000
# Name: Age, dtype: float64

# %% [markdown]
# From the above statistics, it is clear that Customers who have exited are relatively old than the customers who have retained their accounts in the bank

# %%
print("Bank Balance Statistics of Reatined Customers")
print(class_retain['Balance'].describe())
print()
print("Bank Balance Statistics of Exited Customer")
print(class_exit['Balance'].describe())
# Out:
# Bank Balance Statistics of Reatined Customers
# count      7963.000000
# mean      72745.296779
# std       62848.040701
# min           0.000000
# 25%           0.000000
# 50%       92072.680000
# 75%      126410.280000
# max      221532.800000
# Name: Balance, dtype: float64
#
# Bank Balance Statistics of Exited Customer
# count      2037.000000
# mean      91108.539337
# std       58360.794816
# min           0.000000
# 25%       38340.020000
# 50%      109349.290000
# 75%      131433.330000
# max      250898.090000
# Name: Balance, dtype: float64

# %% [markdown]
# From the above statistics, it is clear that the customers who have exited have higher mean balance than the customers who have retained their accounts in the bank

# %% [markdown]
# **SMOTE Balancing**

# %%
X = df.drop('Exited',axis=1)
y = df.Exited

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(sampling_strategy='minority')
X, y = sm.fit_resample(X,y)
y.value_counts()
# Out:
# 1    7963
# 0    7963
# Name: Exited, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
plt.figure(figsize=(5,5))
y.value_counts().plot(kind='bar',colormap='autumn')
plt.title('Retain vs Exit')
plt.xlabel('Status of customers')
plt.ylabel('Number of Customer')
plt.xticks(range(0,2),['Retain','Exit']);

# %% [markdown]
# From the above plot, it is clear that the data is balanced

# %% [markdown]
# # **Modelling the Data**

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier,ExtraTreeClassifier
from sklearn import svm
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import SGDClassifier
from sklearn.neighbors import NearestNeighbors
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,classification_report
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %% [markdown]
# **Evaluation and model testing function**

# %%
def model_scores(models,X_train,X_test,y_train,y_test,X,y):
    model.fit(X_train,y_train)
    preds = model.predict(X_test)
    print('Model Score: ',model.score(X_test, y_test)*100)
    print('Cross-validation score: ',np.mean(cross_val_score(model,X,y,cv=5))*100)
    cm = confusion_matrix(y_test, preds)
    plt.figure(figsize=(5,5))
    plt.title('Confusion Matrix heatmap of '+str(model.__class__.__name__))
    sns.heatmap(cm,annot=True,fmt="d", cmap="Blues", xticklabels=["Predicted 0", "Predicted 1"], yticklabels=["Actual 0", "Actual 1"])
    plt.xlabel("Predicted")
    plt.ylabel("Actual")

# %%
models = {'Random Forest':RandomForestClassifier(),'Decision Tree':DecisionTreeClassifier(),
'Extra Tree':ExtraTreeClassifier(),'Support Vector':svm.SVC(),'Gaussain NB':GaussianNB(),
'SGD':SGDClassifier(),'AdaBoost':AdaBoostClassifier()}

# %% [markdown]
# **Testing Various Models**

# %%
for name,model in models.items():
    print(name)
    model_scores(model,X_train,X_test,y_train,y_test,X,y)
    print()
# Out:
# Random Forest
# Model Score:  85.65599497802887
# Cross-validation score:  85.60899579301517
#
# Decision Tree
# Model Score:  79.00188323917138
# Cross-validation score:  78.92797275363861
#
# Extra Tree
# Model Score:  78.18581293157565
# Cross-validation score:  77.97359523267514
#
# Support Vector
# Model Score:  84.14940364092907
# Cross-validation score:  82.93408465805558
#
# Gaussain NB
# Model Score:  79.8179535467671
# Cross-validation score:  78.72111602862208
#
# SGD
# Model Score:  77.68361581920904
# Cross-validation score:  75.48089808138234
#
# AdaBoost
# Model Score:  82.51726302573759
# Cross-validation score:  82.06127671987235

# %% [markdown]
# The Three models chosen are:
# 1. Random Forest
# 2. Support Vector
# 3. AdaBoost

# %% [markdown]
# **Hyper Tuning Parameters**

# %% [markdown]
# 1. Random Forest

# %%
#random_forest = RandomForestClassifier()

#param_dist = {'n_estimators': np.arange(100, 1000, 100)}

#random_search = RandomizedSearchCV(random_forest, param_distributions=param_dist, n_iter=5, cv=5, random_state=42)

#random_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_iter=5,
#                    param_distributions={'n_estimators': array([100, 200, 300, 400, 500, 600, 700, 800, 900])},
#                    random_state=42)

# %%
#best_params = random_search.best_params_
#best_random = RandomForestClassifier(**best_params)
#model_scores(best_random,X_test,X_train,y_test,y_train)
# Out:
# Model Score:  0.8217425431711146

# %% [markdown]
# 2. Support Vector

# %%
#svc_classifier = svm.SVC()

#param_grid = {'C': [0.1, 1, 10, 100]}

#support_search = RandomizedSearchCV(svc_classifier,param_distributions=param_grid,n_iter=10,cv=5,random_state=42)
#support_search.fit(X_train,y_train)
# Out:
# c:\Users\Dell\ML-course\env\Lib\site-packages\sklearn\model_selection\_search.py:305: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=SVC(),
#                    param_distributions={'C': [0.1, 1, 10, 100]},
#                    random_state=42)

# %%
#best_params = support_search.best_params_
#best_random = svm.SVC(**best_params)
#model_scores(best_random,X_test,X_train,y_test,y_train)
# Out:
# Model Score:  0.8217425431711146

# %% [markdown]
# 3. AdaBoost

# %%
#adaboost_classifier = AdaBoostClassifier()

#param_dist = {'n_estimators': np.arange(50, 500, 50)}

#adaboost_search = RandomizedSearchCV(adaboost_classifier, param_distributions=param_dist, n_iter=10, cv=5, random_state=42)
#adaboost_search.fit(X_train, y_train)
# Out:
# c:\Users\Dell\ML-course\env\Lib\site-packages\sklearn\model_selection\_search.py:305: UserWarning: The total space of parameters 9 is smaller than n_iter=10. Running 9 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=AdaBoostClassifier(),
#                    param_distributions={'n_estimators': array([ 50, 100, 150, 200, 250, 300, 350, 400, 450])},
#                    random_state=42)

# %%
#best_params = adaboost_search.best_params_
#best_random = AdaBoostClassifier(**best_params)
#model_scores(best_random,X_test,X_train,y_test,y_train)
# Out:
# Model Score:  0.8217425431711146

# %% [markdown]
# # **Final Model**

# %%
import joblib

# %%
final_model = RandomForestClassifier()
joblib.dump(final_model,'bank_churn.pkl')
# Out:
# ['bank_churn.pkl']
